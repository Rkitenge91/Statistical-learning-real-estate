# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
#data read in
res_df = pd.read_csv("real_estate_sales.csv")

target_col_names = ["OBJECTID", "SalePrice", "TotalAppraisedValue"]
feat_col_names = ["OBJECTID", "xrCompositeLandUseID", "xrBuildingTypeID", "xrPrimaryNeighborhoodID", "LandSF", "SaleDate", "AssrLandUse"]

target_df = res_df[target_col_names].copy()
feat_df = res_df[feat_col_names].copy()

target_df_filtered = target_df[target_df["SalePrice"]!=1].copy()
target_df_filtered = target_df_filtered[target_df_filtered["SalePrice"]!=0].copy()
target_df_filtered = target_df_filtered[pd.isna(target_df_filtered["SalePrice"]) == False].copy()

#price_dif = target_df["SalePrice"] - target_df["TotalAppraisedValue"]
price_dif = target_df["SalePrice"] / target_df["TotalAppraisedValue"]
#print(price_dif)



dif_dict = {"Price Discrepancy": price_dif}
dif_df = pd.DataFrame(data=dif_dict)

dif_stats_dict = {"Max": dif_df.max(), 
                  "Min": dif_df.min(),
                  "STD": dif_df.std(),
                  "Mean": dif_df.mean(),
                  "Median": dif_df.median()}

dif_stats_df = pd.DataFrame(dif_stats_dict)

#target_df_filtered.head(20)
#feat_df.head()
#target_df.head(20)
#dif_df.head()
#dif_stats_df.head()


#plt.hist(dif_df, bins = 100)
#target_df_filtered.head(20)
#target_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #data read in
# ----> 2 res_df = pd.read_csv("real_estate_sales.csv")
#       4 target_col_names = ["OBJECTID", "SalePrice", "TotalAppraisedValue"]
#       5 feat_col_names = ["OBJECTID", "xrCompositeLandUseID", "xrBuildingTypeID", "xrPrimaryNeighborhoodID", "LandSF", "SaleDate", "AssrLandUse"]
#
# NameError: name 'pd' is not defined
